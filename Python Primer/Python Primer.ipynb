# %%
import importlib
import mod
importlib.reload(mod)

#from mod import fuckkk

pr = print
pr("hi")
mod.say_hello()
abba = mod.suckk()
abba.cls_love()
type(abba)
# Out:
# ############# [ Module mod is loaded ] #############
# hi
# You just ran a module function
# Hi, I'm a new class
# You just ran a class method from a module
# mod.suckk
